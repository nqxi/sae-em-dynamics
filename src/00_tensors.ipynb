# %%
# !pip install torch
import torch
# Out:
# Requirement already satisfied: torch in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (2.11.0)
# Requirement already satisfied: filelock in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (4.13.2)
# Requirement already satisfied: setuptools<82 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cameronmanzo/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)

# %%
# tensor is just an n-dimension array
x = torch.tensor([[1, 0], 
                  [1, 0]])
print(x)
print(x.shape)

y = torch.tensor([[2, 2], 
                  [2, 1]])
print(y)
print(y.shape)
# Out:
# tensor([[1, 0],
#         [1, 0]])
# torch.Size([2, 2])
# tensor([[2, 2],
#         [2, 1]])
# torch.Size([2, 2])

# %%
# Multiply two matrices with torch.chain_matmul
z = torch.matmul(x, y)
print(z)
# Out:
# tensor([[2, 2],
#         [2, 2]])

# %%
# Relu
t = torch.tensor([-3.0, -1.0, 0.0, 2.0, 5.0])                                                            
print(torch.relu(t))
# it sets each negative value to 0 but keeps their position
# im not sure why neural nets need it. what is non linearity?
    # Basically, setting numbers to zero allows for it to learn curves that aren't linear
# Out:
# tensor([0., 0., 0., 2., 5.])

# %%
# Simple neuron
weights = torch.tensor([[0.5, 0.7]
                       ,[0.2, 0.3]])
inputs = torch.tensor([1.0, 2.0])
bias = torch.tensor([0.1, 0.2])

output = torch.relu(torch.matmul(weights, inputs) + bias)

print(output)
# Out:
# tensor([2., 1.])
